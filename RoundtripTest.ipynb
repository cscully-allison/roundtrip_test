# %%
import roundtrip as rt
# %load_ext rt_vis

# %%
# %stacked
# Out:
# <link rel='stylesheet' href='stacked.css'>

# %%
# %canvas_color
# Out:
# <!doctype>
# <html>
# <body>
# <canvas id="myChart" width="800" height="400"></canvas>
#
# <b>Testing bold</b>
# <div>Testing regular</div>
#
# </body>
# </html>

# %%
file_path = "stacked.js"

# Open the file and read its contents
with open(file_path, 'r') as file:
    file_content = file.read()

import json
from IPython.display import display, Javascript, HTML

chartType = 'whatever'
data = [1,2,3]
options = {}
width = 100
height = 100

display(HTML('<link rel="stylesheet" href="stacked.css">'))
display(
    Javascript(file_content % (chartType, json.dumps(data), json.dumps(options), width, height)
                  )
)
# Out:
# <link rel="stylesheet" href="stacked.css">
